# %%
# G-Condition Study
import matplotlib.pyplot as plt
plt.style.use(["science", "ieee"])
import datetime as dt
import sys
sys.path.append("py/")
from fetch import *
import utils

from plot_lib import create_master_plot

# %%
create_master_plot()
# Out:
# 2022-10-11 04:25:19.085 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:19.086 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:19.116 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:25.596 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, NOp
# 2022-10-11 04:25:37.777 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:39.123 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, O2p
# 2022-10-11 04:25:45.508 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:46.841 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, N2p
# 2022-10-11 04:25:53.962 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:25:56.191 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2022-10-11 04:26:03.873 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:26:06.492 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:26:06.492 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:26:06.586 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:26:16.215 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, NOp
# 2022-10-11 04:26:37.223 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:26:57.469 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, O2p
# 2022-10-11 04:27:15.688 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:27:36.412 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, N2p
# 2022-10-11 04:27:54.313 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:28:14.604 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2022-10-11 04:28:32.912 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:28:52.322 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-10-11 04:28:52.323 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk NOp
# 2022-10-11 04:28:56.092 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk O2p
# py/fetch.py:330: RuntimeWarning: divide by zero encountered in log10
#   pnew = 10 ** utils.extrap1d(h, np.log10(param), kind=kind)(self.intp_height)
# 2022-10-11 04:28:59.863 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk N2p
# 2022-10-11 04:29:03.636 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2022-10-11 04:29:07.346 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-10-11 04:29:07.347 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk NOp
# 2022-10-11 04:29:11.130 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk O2p
# 2022-10-11 04:29:14.649 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk N2p
# 2022-10-11 04:29:18.174 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e
# py/plot_lib.py:243: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["", "", "", "", ""])
# 2022-10-11 04:29:23.830 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:29:23.831 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:29:23.835 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-10-11 04:29:30.217 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-10-11 04:29:37.043 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-10-11 04:29:44.001 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, amb_diff
# 2022-10-11 04:29:51.676 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dwind
# 2022-10-11 04:29:59.742 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dfield
# 2022-10-11 04:30:13.784 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:30:13.785 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:30:13.798 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-10-11 04:30:56.123 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-10-11 04:31:10.844 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-10-11 04:31:25.863 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, amb_diff
# 2022-10-11 04:31:41.333 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dwind
# 2022-10-11 04:31:57.737 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dfield
# 2022-10-11 04:32:13.725 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-10-11 04:32:13.725 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-10-11 04:32:17.733 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-10-11 04:32:21.688 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk amb_diff
# 2022-10-11 04:32:25.266 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dwind
# 2022-10-11 04:32:28.845 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dfield
# 2022-10-11 04:32:32.381 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-10-11 04:32:32.382 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-10-11 04:32:36.032 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2022-10-11 04:32:39.710 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk amb_diff
# 2022-10-11 04:32:43.340 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dwind
# 2022-10-11 04:32:47.055 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dfield
# py/plot_lib.py:320: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["", "", "", "", ""])
# py/plot_lib.py:164: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["", "", "", "", ""])

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "amb_diff",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dwind",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dfield",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
# summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
#               types=["1D-TS"])
utils.compute_1D_TS(Hs=[150, 240], vlines=vlines)

# %%
params = [
    {
        "name": "NOp",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "O2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "N2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
              types=["2D-TS-F1"])

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "amb_diff",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dwind",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dfield",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
              types=["2D-TS"])

# %%
# params = [
#     {
#         "name": "Op_CHMP",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "Op_CHML",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "e",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     }
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
#               types=["1D-del"])
