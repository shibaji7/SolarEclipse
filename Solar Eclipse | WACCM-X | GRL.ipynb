# %%
# G-Condition Study
import matplotlib.pyplot as plt
plt.style.use(["science", "ieee"])
import datetime as dt
import sys
sys.path.append("py/")
from fetch import *
import utils

from plot_lib import create_master_plot
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/shibaji/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
create_master_plot()
# Out:
# 2023-01-12 12:15:11.218 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:11.220 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:11.529 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:17.725 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, NOp
# 2023-01-12 12:15:30.460 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:31.805 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, O2p
# 2023-01-12 12:15:38.529 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:39.881 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, N2p
# 2023-01-12 12:15:46.841 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:48.209 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2023-01-12 12:15:55.126 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:15:56.532 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:15:56.533 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:15:56.623 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:16:05.703 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, NOp
# 2023-01-12 12:16:18.548 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:16:21.371 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, O2p
# 2023-01-12 12:16:29.376 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:16:32.164 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, N2p
# 2023-01-12 12:16:40.147 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:16:43.053 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2023-01-12 12:16:51.050 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:16:53.873 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2023-01-12 12:16:53.873 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk NOp
# 2023-01-12 12:16:57.305 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk O2p
# py/fetch.py:330: RuntimeWarning: divide by zero encountered in log10
#   pnew = 10 ** utils.extrap1d(h, np.log10(param), kind=kind)(self.intp_height)
# 2023-01-12 12:17:00.783 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk N2p
# 2023-01-12 12:17:04.169 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2023-01-12 12:17:07.542 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2023-01-12 12:17:07.543 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk NOp
# 2023-01-12 12:17:10.984 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk O2p
# 2023-01-12 12:17:14.444 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk N2p
# 2023-01-12 12:17:17.834 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e
# 2023-01-12 12:17:23.101 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:17:23.101 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:17:23.114 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2023-01-12 12:17:29.268 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2023-01-12 12:17:35.575 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2023-01-12 12:17:42.498 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, amb_diff
# 2023-01-12 12:17:49.765 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dwind
# 2023-01-12 12:17:56.994 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dfield
# 2023-01-12 12:18:04.131 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:18:04.132 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:18:04.198 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2023-01-12 12:18:13.791 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2023-01-12 12:18:19.829 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2023-01-12 12:18:25.889 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, amb_diff
# 2023-01-12 12:18:32.745 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dwind
# 2023-01-12 12:18:39.711 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dfield
# 2023-01-12 12:18:46.665 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2023-01-12 12:18:46.666 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2023-01-12 12:18:50.246 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2023-01-12 12:18:53.501 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk amb_diff
# 2023-01-12 12:18:56.765 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dwind
# 2023-01-12 12:19:00.167 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dfield
# 2023-01-12 12:19:03.521 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2023-01-12 12:19:03.522 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2023-01-12 12:19:06.906 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2023-01-12 12:19:10.235 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk amb_diff
# 2023-01-12 12:19:13.535 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dwind
# 2023-01-12 12:19:16.840 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dfield

# %%
# params = [
#     {
#         "name": "Op_CHMP",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "Op_CHML",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "amb_diff",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "dwind",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "dfield",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "e",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     },
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# # summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
# #               types=["1D-TS"])
# utils.compute_1D_TS(Hs=[150, 240], vlines=vlines)

# %%
# params = [
#     {
#         "name": "NOp",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     },
#     {
#         "name": "O2p",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     },
#     {
#         "name": "N2p",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     },
#     {
#         "name": "e",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     },
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
#               types=["2D-TS-F1"])

# %%
# params = [
#     {
#         "name": "Op_CHMP",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "Op_CHML",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "amb_diff",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "dwind",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "dfield",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
#               types=["2D-TS"])

# %%
# params = [
#     {
#         "name": "Op_CHMP",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "Op_CHML",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "e",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     }
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
#               types=["1D-del"])
