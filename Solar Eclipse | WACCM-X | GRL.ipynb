# %%
# G-Condition Study
import matplotlib.pyplot as plt
plt.style.use(["science", "ieee"])
import datetime as dt
import sys
sys.path.append("py/")
from fetch import *
import utils

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "amb_diff",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dwind",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dfield",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
# summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
#               types=["1D-TS"])
utils.compute_1D_TS(Hs=[150, 240], vlines=vlines)

# %%
params = [
    {
        "name": "NOp",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "O2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "N2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
              types=["2D-TS-F1"])
# Out:
# 2022-08-06 18:36:42.599 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:36:42.600 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:36:42.640 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:36:50.126 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, NOp
# 2022-08-06 18:37:03.122 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:37:04.469 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, O2p
# 2022-08-06 18:37:11.386 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:37:12.720 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, N2p
# 2022-08-06 18:37:20.025 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:37:21.348 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2022-08-06 18:37:28.307 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:37:30.365 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:37:30.366 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:37:30.421 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:37:39.285 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, NOp
# 2022-08-06 18:37:55.700 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:38:08.535 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, O2p
# 2022-08-06 18:38:23.627 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:38:42.091 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, N2p
# 2022-08-06 18:38:58.595 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:39:17.102 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2022-08-06 18:39:33.811 | INFO     | fetch:transform_density:251 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:39:46.811 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-08-06 18:39:46.812 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk NOp
# 2022-08-06 18:39:50.417 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk O2p
# py/fetch.py:330: RuntimeWarning: divide by zero encountered in log10
#   pnew = 10 ** utils.extrap1d(h, np.log10(param), kind=kind)(self.intp_height)
# 2022-08-06 18:39:54.008 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk N2p
# 2022-08-06 18:39:57.573 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2022-08-06 18:40:01.146 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-08-06 18:40:01.147 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk NOp
# 2022-08-06 18:40:04.746 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk O2p
# 2022-08-06 18:40:08.349 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk N2p
# 2022-08-06 18:40:11.946 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "amb_diff",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dwind",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dfield",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 240], vlines=vlines,
              types=["2D-TS"])
# Out:
# 2022-08-06 18:40:23.749 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:40:23.749 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:40:23.900 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-08-06 18:40:31.293 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-08-06 18:40:38.055 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-08-06 18:40:44.904 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, amb_diff
# 2022-08-06 18:40:52.248 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dwind
# 2022-08-06 18:40:59.515 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dfield
# 2022-08-06 18:41:06.729 | INFO     | fetch:__init__:230 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:41:06.730 | INFO     | fetch:load_file:265 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:41:06.854 | INFO     | fetch:extract_dimension:273 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-08-06 18:41:17.059 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-08-06 18:41:23.293 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-08-06 18:41:37.506 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, amb_diff
# 2022-08-06 18:41:51.677 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dwind
# 2022-08-06 18:42:06.489 | INFO     | fetch:run_extractions:292 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dfield
# 2022-08-06 18:42:21.336 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-08-06 18:42:21.337 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-08-06 18:42:24.983 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-08-06 18:42:28.728 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk amb_diff
# 2022-08-06 18:42:32.509 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dwind
# 2022-08-06 18:42:36.314 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dfield
# 2022-08-06 18:42:40.098 | INFO     | fetch:run_height_interpolate:342 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-08-06 18:42:40.098 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-08-06 18:42:43.879 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2022-08-06 18:42:47.671 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk amb_diff
# 2022-08-06 18:42:51.467 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dwind
# 2022-08-06 18:42:55.141 | INFO     | fetch:run_height_interpolate:355 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dfield

# %%
# params = [
#     {
#         "name": "Op_CHMP",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "Op_CHML",
#         "unit_multiplier": 1.0,
#         "unit": "cc",
#         "interpolate": {"scale": "linear", "type": "linear"},
#     },
#     {
#         "name": "e",
#         "unit_multiplier": 1.,
#         "unit": "cc",
#         "mol_to_cc": "T",
#         "interpolate": {"scale": "log", "type": "linear"},
#     }
# ]
# stn = "lusk"
# vlines = [
#     dt.datetime(2017, 8, 21, 16, 15),
#     dt.datetime(2017, 8, 21, 17, 45),
#     dt.datetime(2017, 8, 21, 19, 30),
# ]
# summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
#               types=["1D-del"])
# Out:
# 2022-07-15 16:36:46.843 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:46.844 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:46.915 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:52.471 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-07-15 16:36:57.329 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-07-15 16:37:03.646 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2022-07-15 16:37:15.128 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:37:16.449 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:16.449 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:16.470 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:22.707 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-07-15 16:37:28.143 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-07-15 16:37:40.838 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2022-07-15 16:38:08.897 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:38:29.072 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-07-15 16:38:29.073 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:38:32.545 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 16:38:36.026 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2022-07-15 16:38:39.610 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-07-15 16:38:39.611 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:38:43.233 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 16:38:46.770 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e
