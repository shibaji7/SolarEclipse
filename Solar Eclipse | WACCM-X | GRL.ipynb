# %%
import matplotlib.pyplot as plt
plt.style.use(["science", "ieee"])
import datetime as dt
import sys
sys.path.append("py/")
from fetch import *

# %%
params = [
    {
        "name": "NOp",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "O2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "N2p",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    },
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
              types=["2D-TS-F1"])
# Out:
# 2022-07-15 15:57:25.443 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:57:25.444 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:57:25.669 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:57:32.203 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, NOp
# 2022-07-15 15:57:47.152 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:57:48.505 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, O2p
# 2022-07-15 15:57:55.945 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:57:57.277 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, N2p
# 2022-07-15 15:58:04.641 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:58:06.904 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2022-07-15 15:58:14.566 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 15:58:17.151 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-07-15 15:58:23.518 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-07-15 15:58:30.411 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 15:58:30.411 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 15:58:30.452 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 15:59:10.958 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, NOp
# 2022-07-15 15:59:40.327 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:00:00.266 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, O2p
# 2022-07-15 16:00:23.058 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:00:43.177 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, N2p
# 2022-07-15 16:01:09.449 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:01:24.931 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2022-07-15 16:01:53.724 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:02:04.072 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-07-15 16:02:10.836 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-07-15 16:02:25.874 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-07-15 16:02:26.072 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk NOp
# 2022-07-15 16:02:37.488 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk O2p
# py/fetch.py:296: RuntimeWarning: divide by zero encountered in log10
#   pnew = 10 ** utils.extrap1d(h, np.log10(param), kind=kind)(self.intp_height)
# 2022-07-15 16:02:41.325 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk N2p
# 2022-07-15 16:02:45.027 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2022-07-15 16:02:48.850 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:02:52.332 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 16:02:55.811 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-07-15 16:02:55.812 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk NOp
# 2022-07-15 16:02:59.344 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk O2p
# 2022-07-15 16:03:02.891 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk N2p
# 2022-07-15 16:03:06.445 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e
# 2022-07-15 16:03:10.033 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:03:13.474 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "amb_diff",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dwind",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "dfield",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    }
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
              types=["2D-TS", "1D-TS"])
# Out:
# 2022-07-15 14:35:41.000 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 14:35:41.000 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 14:35:41.234 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 14:35:51.035 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-07-15 14:35:57.523 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-07-15 14:36:04.683 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, amb_diff
# 2022-07-15 14:36:12.318 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dwind
# 2022-07-15 14:36:20.696 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, dfield
# 2022-07-15 14:36:28.268 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 14:36:28.269 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 14:36:28.308 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 14:36:38.187 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-07-15 14:36:43.890 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-07-15 14:36:49.865 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, amb_diff
# 2022-07-15 14:36:58.504 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dwind
# 2022-07-15 14:37:05.638 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, dfield
# 2022-07-15 14:37:20.812 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-07-15 14:37:20.842 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 14:37:24.560 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 14:37:28.208 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk amb_diff
# 2022-07-15 14:37:31.941 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dwind
# 2022-07-15 14:37:35.460 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk dfield
# 2022-07-15 14:37:39.002 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-07-15 14:37:39.002 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 14:37:42.597 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 14:37:46.279 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk amb_diff
# 2022-07-15 14:37:49.846 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dwind
# 2022-07-15 14:37:53.540 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk dfield

# %%
params = [
    {
        "name": "Op_CHMP",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "Op_CHML",
        "unit_multiplier": 1.0,
        "unit": "cc",
        "interpolate": {"scale": "linear", "type": "linear"},
    },
    {
        "name": "e",
        "unit_multiplier": 1.,
        "unit": "cc",
        "mol_to_cc": "T",
        "interpolate": {"scale": "log", "type": "linear"},
    }
]
stn = "lusk"
vlines = [
    dt.datetime(2017, 8, 21, 16, 15),
    dt.datetime(2017, 8, 21, 17, 45),
    dt.datetime(2017, 8, 21, 19, 30),
]
summary_plots(params, stn, Hs=[150, 200, 240, 300], vlines=vlines,
              types=["1D-del"])
# Out:
# 2022-07-15 16:36:46.843 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:46.844 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:46.915 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:36:52.471 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHMP
# 2022-07-15 16:36:57.329 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, Op_CHML
# 2022-07-15 16:37:03.646 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/ECL_1100_0100_all.nc, e
# 2022-07-15 16:37:15.128 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/ECL_1100_0100_all.nc
# 2022-07-15 16:37:16.449 | INFO     | fetch:__init__:196 - Run extraction for dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:16.449 | INFO     | fetch:load_file:231 - Load dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:16.470 | INFO     | fetch:extract_dimension:239 - Run extraction dimension: dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:37:22.707 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHMP
# 2022-07-15 16:37:28.143 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, Op_CHML
# 2022-07-15 16:37:40.838 | INFO     | fetch:run_extractions:258 - Load dataset/29jan2022/BGC_1100_0100_all.nc, e
# 2022-07-15 16:38:08.897 | INFO     | fetch:transform_density:217 - Transform density scale/unit dataset/29jan2022/BGC_1100_0100_all.nc
# 2022-07-15 16:38:29.072 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk
# 2022-07-15 16:38:29.073 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:38:32.545 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 16:38:36.026 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/ECL_1100_0100_all.nc lusk e
# 2022-07-15 16:38:39.610 | INFO     | fetch:run_height_interpolate:308 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk
# 2022-07-15 16:38:39.611 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHMP
# 2022-07-15 16:38:43.233 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk Op_CHML
# 2022-07-15 16:38:46.770 | INFO     | fetch:run_height_interpolate:321 - Run ineterpolation dataset/29jan2022/BGC_1100_0100_all.nc lusk e
